# %% [markdown]
# <a href="https://colab.research.google.com/github/akankshaanilwavhale26-crypto/CSE-Learning-Journey/blob/main/Copy_of_c_program_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile program.c
# #include <stdio.h>
#
# int main() {
#     printf("Hello World");
#     return 0;
# }
# Out:
# Writing program.c

# %%
# !gcc program.c

# %%
# !./a.out
# Out:
# Hello World
